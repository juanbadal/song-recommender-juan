# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import sys
from config import *
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import time
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.manifold import Isomap, TSNE
from umap import UMAP
from sklearn.cluster import KMeans, DBSCAN, HDBSCAN
from sklearn.metrics import silhouette_score as ss
from sklearn.metrics import calinski_harabasz_score as chs
import os
import pickle

# %%
# Loading hot dataset

df_hot = pd.read_csv('hot_songs.csv')

df_hot
# Out:
#                   song_ids                                     song_names  \
# 0   4xhsWYTOGcal8zt0J161CU                                    Lovin On Me
# 1   1BxfuPKGuaTgP7aM0Bbdwr                                   Cruel Summer
# 2   3rUGC1vUpkDG9CZFHMur1t                                         greedy
# 3   2IGMVunIBsBLtEQyoI1Mu7                             Paint The Town Red
# 4   4KULAymBBJcPRpk1yO4dOG  I Remember Everything (feat. Kacey Musgraves)
# ..                     ...                                            ...
# 95  3EvZ03hGAFwGZ2Ebcu86YH                                     Tourniquet
# 96  6RcAHyC5sAUIbPTkhOQwd8                                        Y LLORO
# 97  4tKGFmENO69tZR9ahgZu48                       Murder On The Dancefloor
# 98  505v13epFXodT9fVAJ6h8k                                       AMARGURA
# 99  6d3QUBsiAw3aZI6F2mMhzk   Wildflowers and Wild Horses (Single Version)
#
#            song_artists  danceability  energy   key  loudness  mode  \
# 0           Jack Harlow         0.943   0.558   2.0    -4.911   1.0
# 1          Taylor Swift         0.552   0.702   9.0    -5.707   1.0
# 2            Tate McRae         0.750   0.733   6.0    -3.180   0.0
# 3              Doja Cat         0.868   0.538   5.0    -8.603   1.0
# 4            Zach Bryan         0.429   0.453   0.0    -7.746   1.0
# ..                  ...           ...     ...   ...       ...   ...
# 95           Zach Bryan         0.593   0.397   6.0    -8.309   1.0
# 96             Junior H         0.728   0.589   7.0    -7.115   1.0
# 97  Sophie Ellis-Bextor         0.730   0.849   1.0    -5.281   0.0
# 98              KAROL G         0.920   0.696   6.0    -3.356   0.0
# 99        Lainey Wilson         0.442   0.644  10.0    -5.787   0.0
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.0568       0.00260          0.000002    0.0937    0.606  104.983
# 1        0.1570       0.11700          0.000021    0.1050    0.564  169.994
# 2        0.0319       0.25600          0.000000    0.1140    0.844  111.018
# 3        0.1740       0.26900          0.000003    0.0901    0.732   99.968
# 4        0.0459       0.55400          0.000002    0.1020    0.155   77.639
# ..          ...           ...               ...       ...      ...      ...
# 95       0.0329       0.68400          0.000007    0.0982    0.320   76.703
# 96       0.0376       0.42400          0.000008    0.1660    0.767   77.475
# 97       0.0299       0.00234          0.000026    0.3120    0.887  117.310
# 98       0.0742       0.18300          0.000000    0.1490    0.545  106.966
# 99       0.0378       0.34700          0.000002    0.1280    0.340  117.379
#
#               type                                   uri  \
# 0   audio_features  spotify:track:4xhsWYTOGcal8zt0J161CU
# 1   audio_features  spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# 2   audio_features  spotify:track:3rUGC1vUpkDG9CZFHMur1t
# 3   audio_features  spotify:track:2IGMVunIBsBLtEQyoI1Mu7
# 4   audio_features  spotify:track:4KULAymBBJcPRpk1yO4dOG
# ..             ...                                   ...
# 95  audio_features  spotify:track:3EvZ03hGAFwGZ2Ebcu86YH
# 96  audio_features  spotify:track:6RcAHyC5sAUIbPTkhOQwd8
# 97  audio_features  spotify:track:4tKGFmENO69tZR9ahgZu48
# 98  audio_features  spotify:track:505v13epFXodT9fVAJ6h8k
# 99  audio_features  spotify:track:6d3QUBsiAw3aZI6F2mMhzk
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 1   https://api.spotify.com/v1/tracks/1BxfuPKGuaTg...
# 2   https://api.spotify.com/v1/tracks/3rUGC1vUpkDG...
# 3   https://api.spotify.com/v1/tracks/2IGMVunIBsBL...
# 4   https://api.spotify.com/v1/tracks/4KULAymBBJcP...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/3EvZ03hGAFwG...
# 96  https://api.spotify.com/v1/tracks/6RcAHyC5sAUI...
# 97  https://api.spotify.com/v1/tracks/4tKGFmENO69t...
# 98  https://api.spotify.com/v1/tracks/505v13epFXod...
# 99  https://api.spotify.com/v1/tracks/6d3QUBsiAw3a...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xhs...     138411.0
# 1   https://api.spotify.com/v1/audio-analysis/1Bxf...     178427.0
# 2   https://api.spotify.com/v1/audio-analysis/3rUG...     131872.0
# 3   https://api.spotify.com/v1/audio-analysis/2IGM...     231750.0
# 4   https://api.spotify.com/v1/audio-analysis/4KUL...     227196.0
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/3EvZ...     189053.0
# 96  https://api.spotify.com/v1/audio-analysis/6RcA...     179013.0
# 97  https://api.spotify.com/v1/audio-analysis/4tKG...     230013.0
# 98  https://api.spotify.com/v1/audio-analysis/505v...     170480.0
# 99  https://api.spotify.com/v1/audio-analysis/6d3Q...     216573.0
#
#     time_signature
# 0              4.0
# 1              4.0
# 2              1.0
# 3              4.0
# 4              4.0
# ..             ...
# 95             4.0
# 96             4.0
# 97             4.0
# 98             4.0
# 99             4.0
#
# [100 rows x 20 columns]

# %%
# Loading not hot dataset

df_not_hot = pd.read_csv('not_hot_songs.csv')

df_not_hot.head()
# Out:
#    index  danceability  energy  key  loudness  mode  speechiness  \
# 0      0         0.749   0.802   10    -5.780     0        0.202
# 1      1         0.464   0.602    7    -8.185     1        0.125
# 2      2         0.577   0.692   11    -5.960     1        0.640
# 3      6         0.642   0.694   11    -6.104     1        0.364
# 4      7         0.789   0.488    4    -9.093     0        0.227
#
#    acousticness  instrumentalness  liveness  ...  \
# 0      0.105000          0.000000    0.2960  ...
# 1      0.860000          0.000000    0.1620  ...
# 2      0.372000          0.059600    0.0989  ...
# 3      0.000335          0.000000    0.3120  ...
# 4      0.179000          0.000008    0.1040  ...
#
#                                     uri  \
# 0  spotify:track:5q62CK2DoFxdFBzFDCctDE
# 1  spotify:track:1npAOCsqbB618Zz4jOQxZL
# 2  spotify:track:5zjdL4aLh3D3wOKeRkZSL6
# 3  spotify:track:2TF0kVvksniUGEdwnBSw2v
# 4  spotify:track:23NWj2izXAJ4yL6Nah73wf
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5q62CK2DoFxd...
# 1  https://api.spotify.com/v1/tracks/1npAOCsqbB61...
# 2  https://api.spotify.com/v1/tracks/5zjdL4aLh3D3...
# 3  https://api.spotify.com/v1/tracks/2TF0kVvksniU...
# 4  https://api.spotify.com/v1/tracks/23NWj2izXAJ4...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5q62...      174357
# 1  https://api.spotify.com/v1/audio-analysis/1npA...      162373
# 2  https://api.spotify.com/v1/audio-analysis/5zjd...      122483
# 3  https://api.spotify.com/v1/audio-analysis/2TF0...      143331
# 4  https://api.spotify.com/v1/audio-analysis/23NW...      209453
#
#   time_signature            genre         song_name  title  \
# 0              4  Underground Rap          Big Tyma    NaN
# 1              4  Underground Rap  Mozambique Drill    NaN
# 2              4  Underground Rap       2000 Rounds    NaN
# 3              4  Underground Rap      85 to Africa    NaN
# 4              4  Underground Rap         Pop Style    NaN
#
#                  song_ids artist_name
# 0  5q62CK2DoFxdFBzFDCctDE    Alkaline
# 1  1npAOCsqbB618Zz4jOQxZL  Mach-Hommy
# 2  5zjdL4aLh3D3wOKeRkZSL6  Ghostemane
# 3  2TF0kVvksniUGEdwnBSw2v     Jidenna
# 4  23NWj2izXAJ4yL6Nah73wf       Drake
#
# [5 rows x 24 columns]

# %% [markdown]
# We need to concatenate both dataframes, therefore:
# - We need to ensure they have the same columns with the same names
# - We need to add an extra column identifying if the song is hot or not

# %%
#  Checking shape of both dataframes (we need to concatenate them while adding a column identifying if they are hot or not)

print(df_hot.shape)
print(df_not_hot.shape)
# Out:
# (100, 20)
# (2931, 24)

# %%
# It appears df_not_hot has 3 additional columns, let's check which ones and see if they can be removed

print(df_hot.columns)
print(df_not_hot.columns)
# Out:
# Index(['song_ids', 'song_names', 'song_artists', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'uri',
#        'track_href', 'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')
# Index(['index', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature', 'genre', 'song_name', 'title',
#        'song_ids', 'artist_name'],
#       dtype='object')

# %%
# We might have made an oversight in a previous lab, and the id column in the not hot dataset is duplicated with a different name, let's check if that is the case

df_not_hot['id'].equals(df_not_hot['song_ids'])
# Out:
# True

# %%
# Since it is duplicated, let's remove one of them

df_not_hot = df_not_hot.drop(columns='song_ids')

df_not_hot.shape[1]
# Out:
# 23

# %%
# Title column seems to have a great number of nulls, let's check how many

df_not_hot['title'].isna().sum()
# Out:
# 2931

# %%
# All the values are nulls, let's remove that column as well

df_not_hot = df_not_hot.drop(columns='title')

df_not_hot.shape[1]
# Out:
# 22

# %%
# It appears there is also an index column, does it have unique values in each row?

df_not_hot['index'].nunique()
# Out:
# 2931

# %%
# It indeed does, let's also remove that one

df_not_hot = df_not_hot.drop(columns='index')

df_not_hot.shape[1]
# Out:
# 21

# %%
# Let's standardize column names so we can check which columns both dataframes don't have in common

column_mapping = {'song_ids': 'id', 'song_names': 'song_name', 'song_artists': 'artist_name'}

df_hot = df_hot.rename(columns=column_mapping)

df_hot.columns
# Out:
# Index(['id', 'song_name', 'artist_name', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'type', 'uri', 'track_href',
#        'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
columns_not_in_common = df_hot.columns.difference(df_not_hot.columns).union(df_not_hot.columns.difference(df_hot.columns))
columns_not_in_common
# Out:
# Index(['genre'], dtype='object')

# %%
# In order to concat the dataframes, we will need to remove the genre column. Let's save the current dataframe as a copy just in case we need it in the future

df_not_hot_genre = df_not_hot.copy()

df_not_hot = df_not_hot.drop(columns='genre')

print(df_hot.shape)
print(df_not_hot.shape)
print(df_hot.columns.difference(df_not_hot.columns).union(df_not_hot.columns.difference(df_hot.columns)))
# Out:
# (100, 20)
# (2931, 20)
# Index([], dtype='object')

# %%
# Creating is_hot boolean columns to determine if the song appears in the billboard100 or not

df_hot['is_hot'] = 1

df_not_hot['is_hot'] = 0

display(df_hot.head(1))
display(df_not_hot.head(1))
# Out:
#                        id    song_name  artist_name  danceability  energy  \
# 0  4xhsWYTOGcal8zt0J161CU  Lovin On Me  Jack Harlow         0.943   0.558
#
#    key  loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0  2.0    -4.911   1.0       0.0568        0.0026  ...    0.0937    0.606
#
#      tempo            type                                   uri  \
# 0  104.983  audio_features  spotify:track:4xhsWYTOGcal8zt0J161CU
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4xhs...    138411.0
#
#    time_signature  is_hot
# 0             4.0       1
#
# [1 rows x 21 columns]
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.749   0.802   10     -5.78     0        0.202         0.105
#
#    instrumentalness  liveness  valence  ...            type  \
# 0               0.0     0.296     0.47  ...  audio_features
#
#                        id                                   uri  \
# 0  5q62CK2DoFxdFBzFDCctDE  spotify:track:5q62CK2DoFxdFBzFDCctDE
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5q62CK2DoFxd...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5q62...      174357
#
#    time_signature  song_name artist_name is_hot
# 0               4   Big Tyma    Alkaline      0
#
# [1 rows x 21 columns]

# %%
# Concatenating both dfs into 1

df_all = pd.concat([df_hot, df_not_hot], axis=0)

print(df_all.shape)
df_all.head()
# Out:
# (3031, 21)
#                        id                                      song_name  \
# 0  4xhsWYTOGcal8zt0J161CU                                    Lovin On Me
# 1  1BxfuPKGuaTgP7aM0Bbdwr                                   Cruel Summer
# 2  3rUGC1vUpkDG9CZFHMur1t                                         greedy
# 3  2IGMVunIBsBLtEQyoI1Mu7                             Paint The Town Red
# 4  4KULAymBBJcPRpk1yO4dOG  I Remember Everything (feat. Kacey Musgraves)
#
#     artist_name  danceability  energy  key  loudness  mode  speechiness  \
# 0   Jack Harlow         0.943   0.558  2.0    -4.911   1.0       0.0568
# 1  Taylor Swift         0.552   0.702  9.0    -5.707   1.0       0.1570
# 2    Tate McRae         0.750   0.733  6.0    -3.180   0.0       0.0319
# 3      Doja Cat         0.868   0.538  5.0    -8.603   1.0       0.1740
# 4    Zach Bryan         0.429   0.453  0.0    -7.746   1.0       0.0459
#
#    acousticness  ...  liveness  valence    tempo            type  \
# 0        0.0026  ...    0.0937    0.606  104.983  audio_features
# 1        0.1170  ...    0.1050    0.564  169.994  audio_features
# 2        0.2560  ...    0.1140    0.844  111.018  audio_features
# 3        0.2690  ...    0.0901    0.732   99.968  audio_features
# 4        0.5540  ...    0.1020    0.155   77.639  audio_features
#
#                                     uri  \
# 0  spotify:track:4xhsWYTOGcal8zt0J161CU
# 1  spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# 2  spotify:track:3rUGC1vUpkDG9CZFHMur1t
# 3  spotify:track:2IGMVunIBsBLtEQyoI1Mu7
# 4  spotify:track:4KULAymBBJcPRpk1yO4dOG
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 1  https://api.spotify.com/v1/tracks/1BxfuPKGuaTg...
# 2  https://api.spotify.com/v1/tracks/3rUGC1vUpkDG...
# 3  https://api.spotify.com/v1/tracks/2IGMVunIBsBL...
# 4  https://api.spotify.com/v1/tracks/4KULAymBBJcP...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4xhs...    138411.0
# 1  https://api.spotify.com/v1/audio-analysis/1Bxf...    178427.0
# 2  https://api.spotify.com/v1/audio-analysis/3rUG...    131872.0
# 3  https://api.spotify.com/v1/audio-analysis/2IGM...    231750.0
# 4  https://api.spotify.com/v1/audio-analysis/4KUL...    227196.0
#
#    time_signature  is_hot
# 0             4.0       1
# 1             4.0       1
# 2             1.0       1
# 3             4.0       1
# 4             4.0       1
#
# [5 rows x 21 columns]

# %%
# Removing useless columns

print(df_all['type'].value_counts())

# This column has the same value in every row, let's remove

df_all = df_all.drop(columns='type')

df_all.shape
# Out:
# type
# audio_features    3031
# Name: count, dtype: int64
# (3031, 20)

# %%
# Creating a new dataframe that contains only the features that will be used for clustering

cols_to_drop = ['id', 'song_name', 'artist_name', 'uri', 'track_href', 'analysis_url', 'is_hot']

df_cluster = df_all.drop(columns=cols_to_drop)

df_cluster.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'time_signature'],
#       dtype='object')

# %%
# Exporting both dataframes to csv

df_all.to_csv('songs_features.csv', index=False)

df_cluster.to_csv('songs_cluster.csv', index=False)

# %%
# Scaling values of all columns

scaler = StandardScaler()

scaled = scaler.fit_transform(df_cluster)

path = "scalers/"
isExist = os.path.exists(path)
if not isExist:
    os.makedirs(path)
    print("The new directory is created!")

filename = "standardscaler.pkl"
with open(path+filename, "wb") as file:
    pickle.dump(scaler, file)

df_scaled = pd.DataFrame(scaled, columns=df_cluster.columns)

df_scaled.head()
# Out:
#    danceability    energy       key  loudness      mode  speechiness  \
# 0      1.783216 -0.646429 -0.853702  0.622329  0.820769    -0.760343
# 1     -0.704719  0.171647  1.051325  0.331475  0.820769    -0.026844
# 2      0.555156  0.347760  0.234885  1.254827 -1.218370    -0.942619
# 3      1.305991 -0.760051 -0.037262 -0.726708  0.820769     0.097602
# 4     -1.487369 -1.242943 -1.397995 -0.413565  0.820769    -0.840135
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0     -0.775728         -0.285088 -0.679044  0.698956 -1.465810    -1.067038
# 1     -0.237814         -0.284987 -0.605471  0.515471  0.685143    -0.379150
# 2      0.415770         -0.285100 -0.546873  1.738700 -1.266136    -1.179445
# 3      0.476896         -0.285082 -0.702483  1.249408 -1.631736     0.537488
# 4      1.816978         -0.285089 -0.625004 -1.271316 -2.370513     0.459204
#
#    time_signature
# 0        0.109515
# 1        0.109515
# 2       -8.861798
# 3        0.109515
# 4        0.109515

# %% [markdown]
# ## PCA

# %%
# Dimensionality reduction with PCA

pca = PCA(random_state=69)

principal_components = pca.fit_transform(df_scaled)

df_pca = pd.DataFrame(principal_components, columns=['PCA_'+ str(i) for i in range(1,principal_components.shape[1]+1)])

df_pca.head()
# Out:
#       PCA_1     PCA_2     PCA_3     PCA_4     PCA_5     PCA_6     PCA_7  \
# 0 -0.027550 -1.217422 -1.011184 -2.381625 -0.609341  1.232638  0.112507
# 1 -0.580543 -0.090545  0.107184  0.391132  0.448656  0.472546 -0.655930
# 2 -0.171903  0.289437  0.148566  1.395334  2.456012  7.216707  3.832167
# 3  1.075723 -1.618296  0.008091 -1.801687  0.296004 -0.076105  0.711264
# 4  2.288726  1.600581 -0.809299 -1.864783  1.056080 -0.660715  1.508439
#
#       PCA_8     PCA_9    PCA_10    PCA_11    PCA_12    PCA_13
# 0  0.045479 -0.061139 -0.514197 -0.358697 -0.074036 -0.642055
# 1 -0.781175  1.068864  0.392702  0.132453  0.676098 -0.254500
# 2  3.569219 -0.670942 -0.632552  0.885726  0.066389 -0.523996
# 3  0.602310  0.765341 -0.048939  0.350643  0.356475 -0.013070
# 4 -1.118700 -0.619766  0.349391  0.938429  0.121910 -0.284447

# %%
pca.explained_variance_ratio_
# Out:
# array([0.1747955 , 0.12454692, 0.09857801, 0.08540175, 0.08327606,
#        0.07767862, 0.07237033, 0.06435801, 0.05993759, 0.05635083,
#        0.04957044, 0.03630124, 0.0168347 ])

# %%
cumulated_explained_variance_ratio = [sum(pca.explained_variance_ratio_[0:i+1]) for i,value in enumerate(pca.explained_variance_ratio_)]
cumulated_explained_variance_ratio
# Out:
# [0.17479550272999747,
#  0.29934242258355476,
#  0.3979204316383268,
#  0.4833221793095579,
#  0.5665982374665346,
#  0.6442768579339102,
#  0.7166471894355306,
#  0.7810051998824246,
#  0.8409427898067141,
#  0.8972936235237858,
#  0.946864061242817,
#  0.9831653004373869,
#  0.9999999999999997]

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
ax[0].bar(np.arange(1, len(pca.explained_variance_ratio_) + 1), pca.explained_variance_ratio_)
ax[0].set_xlabel("Principal component")
ax[0].set_title("Variance explained by each Principal Component")
ax[1].bar(np.arange(1, len(pca.explained_variance_ratio_) + 1),cumulated_explained_variance_ratio)
ax[1].set_title("Acumulated variance explained by Principal Components")
ax[1].set_xlabel("Number of Principal components")
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(data=df_pca, x='PCA_1', y='PCA_2')
plt.show()

# %%
fig = go.Figure(data=[go.Scatter3d(
    x=df_pca['PCA_1'],
    y=df_pca['PCA_2'],
    z=df_pca['PCA_3'],
    mode='markers'
)])

fig.update_layout(scene=dict(xaxis_title='PCA_1', yaxis_title='PCA_2', zaxis_title='PCA_3'),
                  title='PCA 3D Scatter Plot')

fig.show()

# %% [markdown]
# ## TruncatedSVD

# %%
# Dimensionality reduction with SVD

svd = TruncatedSVD(n_components=3, random_state=69)

svd_principal_components = svd.fit_transform(df_scaled)

df_svd = pd.DataFrame(svd_principal_components, columns=['SVD_'+ str(i) for i in range(1,svd_principal_components.shape[1]+1)])

df_svd.head()
# Out:
#       SVD_1     SVD_2     SVD_3
# 0 -0.027550 -1.217422 -1.011184
# 1 -0.580543 -0.090545  0.107184
# 2 -0.171903  0.289437  0.148566
# 3  1.075723 -1.618296  0.008091
# 4  2.288726  1.600581 -0.809299

# %%
# 2d scatterplot with first 2 components

sns.scatterplot(data=df_svd, x='SVD_1', y='SVD_2')
plt.show()

# %%
# 3d scatterplot for first 3 components

fig = go.Figure(data=[go.Scatter3d(
    x=df_svd['SVD_1'],
    y=df_svd['SVD_2'],
    z=df_svd['SVD_3'],
    mode='markers'
)])

fig.update_layout(scene=dict(xaxis_title='SVD_1', yaxis_title='SVD_2', zaxis_title='SVD_3'),
                  title='SVD 3D Scatter Plot')

# %% [markdown]
# ## ISOMAP

# %%
# Dimensionality reduction with Isomap

iso = Isomap(n_neighbors=12, n_components=3)
iso.fit(df_scaled)
isomap_transformed = iso.transform(df_scaled)
df_isomap = pd.DataFrame(isomap_transformed, columns=['ISO_1','ISO_2', 'ISO_3'])
df_isomap.head()
# Out:
#       ISO_1      ISO_2     ISO_3
# 0  4.045286  -0.119658  0.258680
# 1  4.338355  -0.550930 -0.308075
# 2  6.751487  24.995195 -3.428258
# 3  4.015355   1.161563 -0.741782
# 4  3.969484   4.084222  1.823675

# %%
# 2d scatterplot with first 2 components

sns.scatterplot(data=df_isomap, x='ISO_1', y='ISO_2')
plt.show()

# %%
# 3d scatterplot for first 3 components

fig = go.Figure(data=[go.Scatter3d(
    x=df_isomap['ISO_1'],
    y=df_isomap['ISO_2'],
    z=df_isomap['ISO_3'],
    mode='markers'
)])

fig.update_layout(scene=dict(xaxis_title='ISO_1', yaxis_title='ISO_2', zaxis_title='ISO_3'),
                  title='Isomap 3D Scatter Plot')

fig.show()

# %% [markdown]
# ## TSNE

# %%
# Dimensionality reduction with TSNE

tsne = TSNE(n_components=3, random_state=69)
tsne_transformed = tsne.fit_transform(df_scaled)

df_tsne = pd.DataFrame(tsne_transformed, columns=['TSNE_1', 'TSNE_2', 'TSNE_3'])
df_tsne.head()
# Out:
#       TSNE_1     TSNE_2     TSNE_3
# 0  -2.327960  -0.258297  -8.072962
# 1   0.289335 -10.242224 -14.412291
# 2 -10.004911 -19.248104   1.253518
# 3   8.092173  -3.580091 -15.329898
# 4  11.891590  -0.640380  -3.363129

# %%
# 2d scatterplot with first 2 components

sns.scatterplot(data=df_tsne, x='TSNE_1', y='TSNE_2')
plt.show()

# %%
# 3d scatterplot for first 3 components

fig = go.Figure(data=[go.Scatter3d(
    x=df_tsne['TSNE_1'],
    y=df_tsne['TSNE_2'],
    z=df_tsne['TSNE_3'],
    mode='markers'
)])

fig.update_layout(scene=dict(xaxis_title='TSNE_1', yaxis_title='TSNE_2', zaxis_title='TSNE_3'),
                  title='Isomap 3D Scatter Plot')

fig.show()

# %% [markdown]
# ## UMAP

# %%
umap = UMAP(n_components=3, random_state=69)
umap.fit(df_scaled)

umap_transformed = umap.transform(df_scaled)
df_umap = pd.DataFrame(umap_transformed, columns=['UMAP_1','UMAP_2', 'UMAP_3'])
df_umap.head()
# Out:
# c:\Users\Juan\AppData\Local\Programs\Python\Python39\lib\site-packages\umap\umap_.py:1943: UserWarning:
#
# n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#       UMAP_1    UMAP_2     UMAP_3
# 0  10.322562  1.189015   9.460398
# 1   9.495350 -0.471293  10.551485
# 2  -4.868626  3.840348  10.734679
# 3   8.650017 -0.127352  10.885015
# 4   8.108695  1.434146   9.357534

# %%
sns.scatterplot(data=df_umap, x='UMAP_1', y='UMAP_2')
plt.show()

# %%
# 3d scatterplot for first 3 components

fig = go.Figure(data=[go.Scatter3d(
    x=df_umap['UMAP_1'],
    y=df_umap['UMAP_2'],
    z=df_umap['UMAP_3'],
    mode='markers'
)])

fig.update_layout(scene=dict(xaxis_title='UMAP_1', yaxis_title='UMAP_2', zaxis_title='UMAP_3'),
                  title='Isomap 3D Scatter Plot')

fig.show()

# %% [markdown]
# ## Clustering with HDBSCAN

# %%
# Saving UMAP model

path = "models/"
isExist = os.path.exists(path)
if not isExist:
    os.makedirs(path)
    print("The new directory is created!")

filename = "umap.pkl"
with open(path+filename, "wb") as file:
    pickle.dump(umap, file)

# %%
# Using UMAP as our dimensionality reduction technique

# If our df already has a labels column, drop it
if 'labels' in df_umap.columns:
    df_umap = df_umap.drop(columns='labels')

# HDBSCAN clustering
hdbscan = HDBSCAN(min_cluster_size=(df_umap.shape[1] * 2), cluster_selection_epsilon=1)
cluster_labels = hdbscan.fit_predict(df_umap)

# Add the new 'labels' column
df_umap['labels'] = cluster_labels

# Create 3D scatter plot
fig = go.Figure(data=[go.Scatter3d(
    x=df_umap['UMAP_1'],
    y=df_umap['UMAP_2'],
    z=df_umap['UMAP_3'],
    mode='markers',
    marker=dict(
        color=df_umap['labels'],
        colorscale='Viridis',
        colorbar=dict(title='labels')
    )
)])

fig.update_layout(scene=dict(xaxis_title='UMAP_1', yaxis_title='UMAP_2', zaxis_title='UMAP_3'),
                  title='UMAP + HDBSCAN 3D Scatter Plot')

fig.show()

# %%
# Saving HDBSCAN model

path = "models/"
isExist = os.path.exists(path)
if not isExist:
    os.makedirs(path)
    print("The new directory is created!")

filename = "hdbscan.pkl"
with open(path+filename, "wb") as file:
    pickle.dump(hdbscan, file)
